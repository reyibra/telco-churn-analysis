# %% [markdown]
# ## Project overview, Why we analyze churn and questions to answer.

# %% [markdown]
# ## Load data

# %%
import pandas as pd
df = pd.read_csv('../data/raw/telco_secret.csv')
df.head()
# Out:
#   customerID  gender  senior_citizen dependents  tenure        contract  \
# 0  CUST00001  Female               1         No      52        One year
# 1  CUST00002    Male               0        Yes      46  Month-to-month
# 2  CUST00003    Male               0        Yes      53  Month-to-month
# 3  CUST00004  Female               0        Yes      18        One year
# 4  CUST00005  Female               0        Yes      42  Month-to-month
#
#   internet_service online_security tech_support streaming_tv  monthly_charges  \
# 0      Fiber optic              No           No          Yes           114.00
# 1              DSL             Yes           No          Yes           137.98
# 2              DSL             Yes          Yes           No            51.29
# 3      Fiber optic              No           No          Yes           112.47
# 4      Fiber optic             Yes          Yes          Yes            63.84
#
#    total_charges             payment_method  app_usage_min_per_week  \
# 0        5932.80    Credit card (automatic)                     492
# 1        6350.44               Mailed check                     497
# 2        2721.75  Bank transfer (automatic)                     358
# 3        2025.34               Mailed check                     486
# 4        2718.73               Mailed check                     486
#
#    complaint_count_6m  satisfaction_rating  engagement_score churn
# 0                   0                    1             0.551   Yes
# 1                   0                    6             0.733    No
# 2                   2                    5             0.546    No
# 3                   0                    5             0.686    No
# 4                   4                    1             0.451   Yes

# %% [markdown]
# ## Initial checks

# %%
print(df.shape)
print(df.isnull().sum())
# Out:
# (3000, 18)
# customerID                0
# gender                    0
# senior_citizen            0
# dependents                0
# tenure                    0
# contract                  0
# internet_service          0
# online_security           0
# tech_support              0
# streaming_tv              0
# monthly_charges           0
# total_charges             0
# payment_method            0
# app_usage_min_per_week    0
# complaint_count_6m        0
# satisfaction_rating       0
# engagement_score          0
# churn                     0
# dtype: int64

# %% [markdown]
# ## Distribution & plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(data=df, x='churn')
plt.show()
