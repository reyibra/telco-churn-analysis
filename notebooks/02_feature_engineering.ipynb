# %% [markdown]
# ## Plan\n\nList of candidate features and transformations.

# %% [markdown]
# ## Encoding & new features\n\n

# %%
import pandas as pd
df = pd.read_csv('../data/raw/telco_secret.csv')
df['tenure_bucket'] = pd.cut(df['tenure'], bins=[-1,6,24,48,100], labels=['0-6','7-24','25-48','49+'])
df.head()
